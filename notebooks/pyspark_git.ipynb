-- %% [markdown]
-- ### ## # **Practice PySpark Code**

-- %%
%python
# Sample Data
data = [(1,"Ram","Databricks Platform Engineer", 100000),
        (2,"Saketh","Resident Solutions Architect",200000),
        (3,"Hruday","Cloud Architect",250000)]
# Columns
columns = ["id","name","designation","salary"]

# Create Dataframe
df = spark.createDataFrame(data,columns)

# Display table
df.show()
